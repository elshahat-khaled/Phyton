# %%
import pymongo 
import pandas as pd

# %%
client = pymongo.MongoClient(
    "mongodb://khaled:33311Ee9@cluster0-shard-00-00.2e0wc.mongodb.net:27017,cluster0-shard-00-01.2e0wc.mongodb.net:27017,cluster0-shard-00-02.2e0wc.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-3iutc4-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.Elshahat

# %%
df = db.consolati_italiani.find_one()
df
# Out:
# {'_id': ObjectId('623d88bd7dd56dbed7429f53'),
#  'capomissione': 'DE RIU ANTONELLO',
#  'continente': 'Asia',
#  'email': 'consolato.hongkong@esteri.it',
#  'funzionecapo': 'CONSOLE GENERALE',
#  'idtiposede': '4',
#  'indirizzo': 'Suite 3201, Central Plaza, 18 Harbour Road, Wanchai - Hong Kong',
#  'lat': '22.396428',
#  'lng': '114.109497',
#  'paese': 'REPUBBLICA POPOLARE CINESE',
#  'sede': 'CONSOLATO GENERALE - HONG KONG',
#  'sitoweb': 'www.conshongkong.esteri.it'}

# %%
df = pd.DataFrame.from_records(db.consolati_italiani.find())
df
# Out:
#                           _id  \
# 0    623d88bd7dd56dbed7429f53
# 1    623d88bd7dd56dbed7429f5a
# 2    623d88bd7dd56dbed7429f44
# 3    623d88bd7dd56dbed7429f50
# 4    623d88bd7dd56dbed7429f52
# ..                        ...
# 446  623d88bd7dd56dbed742a0d2
# 447  623d88bd7dd56dbed742a0d3
# 448  623d88bd7dd56dbed742a0e4
# 449  623d88bd7dd56dbed742a0eb
# 450  623d88bd7dd56dbed742a101
#
#                                                   sede idtiposede  \
# 0                       CONSOLATO GENERALE - HONG KONG          4
# 1                           CONSOLATO GENERALE - OSAKA          4
# 2          CONSOLATO GENERALE DI PRIMA CLASSE - ZURIGO          3
# 3        CONSOLATO GENERALE - LOS ANGELES (California)          4
# 4                      CONSOLATO GENERALE - BARCELLONA          4
# ..                                                 ...        ...
# 446             AGENZIA CONSOLARE ONORARIA - CEFALONIA         12
# ...

# %% [markdown]
# 1. il cognome e il nome dei capomissione con la loro funzione

# %%
result=db.consolati_italiani.find({},{"capomissione":1,"_id":0,"funzionecapo":1})
df = pd.DataFrame(list(result))
df
# Out:
#                     capomissione               funzionecapo
# 0               DE RIU ANTONELLO           CONSOLE GENERALE
# 1                  DIODATI LUIGI           CONSOLE GENERALE
# 2                  ALAIMO GIULIO           CONSOLE GENERALE
# 3                  VERDE ANTONIO           CONSOLE GENERALE
# 4            DANESE GAIA LUCILLA           CONSOLE GENERALE
# ..                           ...                        ...
# 446         MICHELETTI GRAZIELLA  Agente consolare onorario
# 447         PAGONA REKAITI MARIA  Agente consolare onorario
# 448         INSALACO MANTA MARIA  Agente consolare onorario
# 449    GHERARDI PALANGE GIUSEPPE  Agente consolare onorario
# 450  BARTOCCIONI ALBERTO GUSTAVO  Agente consolare onorario
#
# [451 rows x 2 columns]

# %% [markdown]
# 2.l'indirizzo del consolato di zurigo

# %%
result=db.consolati_italiani.find({"indirizzo":{"$regex":"Zurigo"}})
df = pd.DataFrame(list(result))
df[['sede','paese','indirizzo']]
# Out:
#                                           sede     paese  \
# 0  CONSOLATO GENERALE DI PRIMA CLASSE - ZURIGO  SVIZZERA
#
#                        indirizzo
# 0  Tödistrasse, 65 - 8002 Zurigo

# %% [markdown]
# 3.l'elenco dei consolati generali.ordinare in ordine alfabetico

# %%
result = db.consolati_italiani.aggregate([{"$unwind": "$sede"},
                              {"$sort":{"sede":-1}}
                              ])

df = pd.DataFrame(list(result))
df
# Out:
#                           _id  \
# 0    623d88bd7dd56dbed742a049
# 1    623d88bd7dd56dbed742a0c0
# 2    623d88bd7dd56dbed742a06a
# 3    623d88bd7dd56dbed742a089
# 4    623d88bd7dd56dbed742a058
# ..                        ...
# 446  623d88bd7dd56dbed742a0eb
# 447  623d88bd7dd56dbed742a0d7
# 448  623d88bd7dd56dbed7429f90
# 449  623d88bd7dd56dbed7429f91
# 450  623d88bd7dd56dbed7429f92
#
#                                                   sede idtiposede  \
# 0                 VICE CONSOLATO ONORARIO - WOLLONGONG         11
# 1        VICE CONSOLATO ONORARIO - WINNIPEG (Manitoba)         11
# 2          VICE CONSOLATO ONORARIO - WINDSOR (Ontario)         11
# 3                      VICE CONSOLATO ONORARIO - VOLOS         11
# 4                      VICE CONSOLATO ONORARIO - VISBY         11
# ..                                                 ...        ...
# 446               AGENZIA CONSOLARE ONORARIA - BARINAS         12
# ...

# %%
result = db.consolati_italiani.find({"sede":{"$regex":"CONSOLATO GENERALE"}}).sort("sede",1)
df = pd.DataFrame(list(result))
df
# Out:
#                          _id  \
# 0   623d88bd7dd56dbed7429f55
# 1   623d88bd7dd56dbed7429f52
# 2   623d88bd7dd56dbed7429f6f
# 3   623d88bd7dd56dbed7429f77
# 4   623d88bd7dd56dbed7429f4e
# ..                       ...
# 66  623d88bd7dd56dbed7429f9c
# 67  623d88bd7dd56dbed7429f94
# 68  623d88bd7dd56dbed7429f93
# 69  623d88bd7dd56dbed7429f99
# 70  623d88bd7dd56dbed7429f96
#
#                                                  sede idtiposede          lat  \
# 0    CONSOLATO GENERALE - BAHIA BLANCA (Buenos Aires)          4  -38.7116583
# 1                     CONSOLATO GENERALE - BARCELLONA          4   41.3948056
# 2                        CONSOLATO GENERALE - BENGASI          4    32.117257
# 3         CONSOLATO GENERALE - BOSTON (Massachusetts)          4   42.3525558
# 4                   CONSOLATO GENERALE - BUENOS AIRES          4   -34.601193
# ..                                                ...        ...          ...
# ...

# %%
result=db.consolati_italiani.find({},{"sede":1,"_id":0,"paese":1}).sort([("sede", 1)])
df = pd.DataFrame(list(result))
df
# Out:
#                                                   sede      paese
# 0    AGENZIA CONSOLARE - LOMAS DE ZAMORA (Buenos Ai...  ARGENTINA
# 1             AGENZIA CONSOLARE - MORON (Buenos Aires)  ARGENTINA
# 2                        AGENZIA CONSOLARE - WOLFSBURG   GERMANIA
# 3                AGENZIA CONSOLARE ONORARIA - AALESUND   NORVEGIA
# 4                 AGENZIA CONSOLARE ONORARIA - BARINAS  VENEZUELA
# ..                                                 ...        ...
# 446                    VICE CONSOLATO ONORARIO - VISBY     SVEZIA
# 447                    VICE CONSOLATO ONORARIO - VOLOS     GRECIA
# 448        VICE CONSOLATO ONORARIO - WINDSOR (Ontario)     CANADA
# 449      VICE CONSOLATO ONORARIO - WINNIPEG (Manitoba)     CANADA
# 450               VICE CONSOLATO ONORARIO - WOLLONGONG  AUSTRALIA
#
# [451 rows x 2 columns]

# %% [markdown]
# 4.il numero complessivo di consoli generali

# %%
result=db.consolati_italiani.count_documents({"funzionecapo":"CONSOLE GENERALE"})
result
# Out:
# 46

# %% [markdown]
# 5.i consolati che si trovano nell'emisfero australe

# %%
result=db.consolati_italiani.find({"lat":{"$lt":"0"}})
df = pd.DataFrame(list(result))
df
# Out:
#                          _id  \
# 0   623d88bd7dd56dbed7429f43
# 1   623d88bd7dd56dbed7429f82
# 2   623d88bd7dd56dbed742a08f
# 3   623d88bd7dd56dbed742a0a6
# 4   623d88bd7dd56dbed742a0d8
# ..                       ...
# 85  623d88bd7dd56dbed7429f69
# 86  623d88bd7dd56dbed7429f8f
# 87  623d88bd7dd56dbed742a04a
# 88  623d88bd7dd56dbed742a0b9
# 89  623d88bd7dd56dbed742a101
#
#                                                  sede idtiposede          lat  \
# 0      CONSOLATO GENERALE DI PRIMA CLASSE - SAN PAOLO          3   -23.559803
# 1        CONSOLATO - ADELAIDE (Australia Meridionale)          6   -34.893746
# 2                VICE CONSOLATO ONORARIO - CORRIENTES         11   -27.471762
# 3   VICE CONSOLATO ONORARIO - CAMPO GRANDE (Mato G...         11   -20.465283
# 4   AGENZIA CONSOLARE ONORARIA - LAS VARILLAS (Cor...         12  -31.8719864
# ..                                                ...        ...          ...
# ...

# %% [markdown]
# 6.l'elnco dei consolati presenti in argentina

# %%
result=db.consolati_italiani.find({"paese":"ARGENTINA"})
df = pd.DataFrame(list(result))
df

# %%
result = db.consolati_italiani.aggregate([{"$unwind": "$sede"},
                              {"$match": {"paese": "ARGENTINA"}},
                              {"$project": {"_id": 0, "sede": 1, "paese" :1 }}])

df = pd.DataFrame(list(result))
df
# Out:
#                                                  sede      paese
# 0                VICE CONSOLATO ONORARIO - CORRIENTES  ARGENTINA
# 1   AGENZIA CONSOLARE ONORARIA - LAS VARILLAS (Cor...  ARGENTINA
# 2    CONSOLATO GENERALE - BAHIA BLANCA (Buenos Aires)  ARGENTINA
# 3                  VICE CONSOLATO ONORARIO - LA RIOJA  ARGENTINA
# 4          AGENZIA CONSOLARE ONORARIA - PUERTO MADRYN  ARGENTINA
# 5   AGENZIA CONSOLARE ONORARIA - TANDIL (Buenos Ai...  ARGENTINA
# 6    VICE CONSOLATO ONORARIO - QUILMES (Buenos Aires)  ARGENTINA
# 7        VICE CONSOLATO ONORARIO - VIEDMA (Rio Negro)  ARGENTINA
# 8   AGENZIA CONSOLARE - LOMAS DE ZAMORA (Buenos Ai...  ARGENTINA
# 9        VICE CONSOLATO ONORARIO - POSADAS (Misiones)  ARGENTINA
# 10  VICE CONSOLATO ONORARIO - NECOCHEA (Buenos Aires)  ARGENTINA
# 11                  VICE CONSOLATO ONORARIO - TUCUMAN  ARGENTINA
# 12               AGENZIA CONSOLARE ONORARIA - RAFAELA  ARGENTINA
# ...

# %% [markdown]
# 7.l'elnco dei consolati presenti in argentina e in brasile

# %%
result=db.consolati_italiani.find({"$or":[{"paese":"ARGENTINA"},{"paese": "BRASILE"}]})
df = pd.DataFrame(list(result))
df
# Out:
#                          _id  \
# 0   623d88bd7dd56dbed7429f43
# 1   623d88bd7dd56dbed742a08f
# 2   623d88bd7dd56dbed742a0a6
# 3   623d88bd7dd56dbed742a0d8
# 4   623d88bd7dd56dbed742a0e9
# ..                       ...
# 75  623d88bd7dd56dbed742a0e2
# 76  623d88bd7dd56dbed7429f69
# 77  623d88bd7dd56dbed7429f8f
# 78  623d88bd7dd56dbed742a04a
# 79  623d88bd7dd56dbed742a101
#
#                                                  sede idtiposede          lat  \
# 0      CONSOLATO GENERALE DI PRIMA CLASSE - SAN PAOLO          3   -23.559803
# 1                VICE CONSOLATO ONORARIO - CORRIENTES         11   -27.471762
# 2   VICE CONSOLATO ONORARIO - CAMPO GRANDE (Mato G...         11   -20.465283
# 3   AGENZIA CONSOLARE ONORARIA - LAS VARILLAS (Cor...         12  -31.8719864
# 4   AGENZIA CONSOLARE ONORARIA - SAO JOSE' DO RIO ...         12  -20.8204749
# ..                                                ...        ...          ...
# ...

# %%
result = db.consolati_italiani.aggregate([{"$unwind": "$sede"},
                              {"$match": {"paese": "ARGENTINA","paese": "BRASILE"}},
                              {"$project": {"_id": 0, "sede": 1, "paese" :1 }}])

df = pd.DataFrame(list(result))
df

# %% [markdown]
# 8.i consolati di cui non si conosce il sito web

# %%
result=db.consolati_italiani.find({},{"sitoweb": None})
df = pd.DataFrame(list(result))
df
# Out:
#                           _id sitoweb
# 0    623d88bd7dd56dbed7429f53    None
# 1    623d88bd7dd56dbed7429f5a    None
# 2    623d88bd7dd56dbed7429f44    None
# 3    623d88bd7dd56dbed7429f50    None
# 4    623d88bd7dd56dbed7429f52    None
# ..                        ...     ...
# 446  623d88bd7dd56dbed742a0d2    None
# 447  623d88bd7dd56dbed742a0d3    None
# 448  623d88bd7dd56dbed742a0e4    None
# 449  623d88bd7dd56dbed742a0eb    None
# 450  623d88bd7dd56dbed742a101    None
#
# [451 rows x 2 columns]

# %%
result = db.consolati_italiani.aggregate([{"$unwind": "$sede"},
                              { "sitoweb": { "$nin": [ "" ] }},
                              {"$project": {"_id": 0, "sede": 1, "sitoweb" :1 }}])

df = pd.DataFrame(list(result))
df
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-18-be2c5d945e58> in <module>()
#       1 result = db.consolati_italiani.aggregate([{"$unwind": "$sede"},
#       2                               { "sitoweb": { "$nin": [ "" ] }},
# ----> 3                               {"$project": {"_id": 0, "sede": 1, "sitoweb" :1 }}])
#       4
#       5 df = pd.DataFrame(list(result))
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in aggregate(self, pipeline, session, **kwargs)
#    2108                 session=s,
#    2109                 explicit_session=session is not None,
# -> 2110                 **kwargs
#    2111             )
#    2112
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, **kwargs)
# ...

# %% [markdown]
# 9.i consolati che non hanno una mail del Ministero degli Esteri

# %%
result=db.consolati_italiani.find({"email":{"$not":{"$regex":"@esteri.it"}}})
df = pd.DataFrame(list(result))
df
# Out:
#                           _id  \
# 0    623d88bd7dd56dbed742a00b
# 1    623d88bd7dd56dbed742a035
# 2    623d88bd7dd56dbed742a059
# 3    623d88bd7dd56dbed742a06a
# 4    623d88bd7dd56dbed742a08f
# ..                        ...
# 241  623d88bd7dd56dbed742a0a8
# 242  623d88bd7dd56dbed742a0d2
# 243  623d88bd7dd56dbed742a0d3
# 244  623d88bd7dd56dbed742a0eb
# 245  623d88bd7dd56dbed742a101
#
#                                                   sede idtiposede  \
# 0                           CONSOLATO ONORARIO - HAIFA         10
# 1                CONSOLATO ONORARIO - BELFAST (Antrim)         10
# 2                  VICE CONSOLATO ONORARIO - BEERSHEVA         11
# 3          VICE CONSOLATO ONORARIO - WINDSOR (Ontario)         11
# 4                 VICE CONSOLATO ONORARIO - CORRIENTES         11
# ..                                                 ...        ...
# 241       VICE CONSOLATO ONORARIO - COPIAPO' (Atacama)         11
# ...

# %% [markdown]
# 10.il numero di consolati in ogni continente

# %%
result = db.consolati_italiani.aggregate([
                {"$group" : {"_id": "$continente", "total" : {"$sum" : 1}}},
                { "$sort": {"_id": 1 }}
                ])
df = pd.DataFrame(list(result))
df
# Out:
#                 _id  total
# 0            Africa     31
# 1              Asia     49
# 2            Europe    160
# 3  Northern America     63
# 4           Oceania     15
# 5     South America    133

# %%
result = db.consolati_italiani.aggregate([{ "$unwind": "$continente" },
                              { "$group" : {"_id": "$continente", "total" : {"$sum" : 1}}},
                              { "$project": {"_id": 0,"continente": "$_id","total": "$total"}}])
df = pd.DataFrame(list(result))
df

# %% [markdown]
# esercizio 11 i continenti che hanno più di 50 consolati. Ordinare in ordine decrescente a partire dal continente che ha più consolati

# %%
result = db.consolati_italiani.aggregate([
                {"$group" : {"_id": "$continente", "total" : {"$sum" : 1}}},
                {"$match":{"total":{"$gt":50}}},
                { "$sort": {"total": -1 }}
                ])
df = pd.DataFrame(list(result))
df
# Out:
#                 _id  total
# 0            Europe    160
# 1     South America    133
# 2  Northern America     63

# %%
result = db.consolati_italiani.aggregate([{ "$unwind": "$continente" },
                              { "$group" : {"_id": "$continente", "total" : {"$sum" : 1}}},
                              { "$match": { "total": { "$gt": 50 }}},
                              { "$sort": {"total": -1 }},
                              { "$project": {"_id": 0,"continente": "$_id","total": "$total"}}])
df = pd.DataFrame(list(result))
df

# %% [markdown]
# esrcizio 12 il paese che ha più consolati

# %%
result = db.consolati_italiani.aggregate([{ "$unwind": "$continente" },
                              { "$group" : {"_id": "$continente", "total" : {"$sum" : 1}}},
                              { "$match": { "total": { "$gt": 50 }}},
                              { "$sort": {"total": -1 }},
                              { "$project": {"_id": 0,"continente": "$_id","total": "$total"}}])
df = pd.DataFrame(list(result))
df.head(1)

# %%
import pymongo 
import pandas as pd

# %%
client = pymongo.MongoClient("mongodb://Emanuele-Visioli:EMAnuele25102004@cluster0-shard-00-00.x7fma.mongodb.net:27017,cluster0-shard-00-01.x7fma.mongodb.net:27017,cluster0-shard-00-02.x7fma.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-566dc8-shard-0&authSource=admin&retryWrites=true&w=majority")

db = client.sample_supplies

# %%
db.sales.find()
df = pd.DataFrame(list(db.sales.find()))

# %%
client = pymongo.MongoClient("mongodb://Santambrogio:wwwws6Ss@cluster0-shard-00-00.r4fcr.mongodb.net:27017,cluster0-shard-00-01.r4fcr.mongodb.net:27017,cluster0-shard-00-02.r4fcr.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-yc014g-shard-0&authSource=admin&retryWrites=true&w=majority")
db2 = client.Santambrogio

# %%
db2.vendite.insert_many(df.to_dict("records"))

# %%
df = pd.DataFrame(list(db2.vendite.find()))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 4650  5bd761deae323e45a93ce33e 2015-11-25 21:06:13.187
# 4651  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 4652  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 4653  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'pens', 'tags': ['writing', 'office'...       Seattle
# 1     [{'name': 'printer paper', 'tags': ['office', ...      New York
# 2     [{'name': 'pens', 'tags': ['writing', 'office'...        Denver
# ...

# %% [markdown]
# # 1. cancellare tutti i document relativi al negozio di San Diego

# %%
result = db2.vendite.delete_many({"storeLocation" : "San Diego"})
result.deleted_count
# Out:
# 0

# %% [markdown]
# # 2. invecchiare i clienti di 8 anni

# %%
result = db2.vendite.update_many({},{"$inc" : {"costumer.age": 8}}) # $inc incrementa di un tot quello che abbiamo scelto, sempre inc ma con - per decrementare
result.modified_count
# Out:
# 4654

# %% [markdown]
# # 3. cancellare tutti i tag 'stationary'

# %%
result = db2.vendite.find({"items.tags": "stationary"})
df = pd.DataFrame(list(result))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4085  5bd761deae323e45a93ce337 2014-04-29 05:00:20.567
# 4086  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 4087  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 4088  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 4089  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'pens', 'tags': ['writing', 'office'...       Seattle
# 1     [{'name': 'printer paper', 'tags': ['office', ...      New York
# 2     [{'name': 'pens', 'tags': ['writing', 'office'...        Denver
# ...

# %%
result = db2.vendite.update_many({},{"$pull" : {"items" :{ "tags": "stationary"}}}) #$pull per togliere i dati, #$push per inserirli
result.modified_count
# Out:
# 4090

# %% [markdown]
# # 4. eliminare tutti i document di clienti che hanno più di 80 anni e meno di 40

# %%
result = db2.vendite.find({'$or': [{"customer.age" : {'$gt' : 80 }} , {"customer.age" : {'$lt' : 40 }}]})
df = pd.DataFrame(list(result))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccffc 2015-11-12 12:06:07.052
# 3     5bd761dcae323e45a93cd002 2015-04-18 03:33:09.638
# 4     5bd761dcae323e45a93cd024 2013-09-20 14:23:01.776
# ...                        ...                     ...
# 1812  5bd761deae323e45a93ce203 2016-12-02 17:57:12.144
# 1813  5bd761deae323e45a93ce262 2013-02-04 08:12:59.540
# 1814  5bd761deae323e45a93ce27f 2017-02-13 21:26:28.310
# 1815  5bd761deae323e45a93ce2bc 2015-11-06 00:15:27.205
# 1816  5bd761deae323e45a93ce33e 2015-11-25 21:06:13.187
#
#                                                   items storeLocation  \
# 0     [{'name': 'backpack', 'tags': ['school', 'trav...       Seattle
# 1     [{'name': 'binder', 'tags': ['school', 'genera...      New York
# 2     [{'name': 'binder', 'tags': ['school', 'genera...        Denver
# ...

# %%
result = db2.vendite.delete_many({'$or': [{"customer.age" : {'$gt' : 80 }} , {"customer.age" : {'$lt' : 40 }}]})
result.deleted_count
# Out:
# 1817

# %% [markdown]
# # 5. calcolare il prezzo medio degli items

# %%
result = db2.vendite.aggregate([{"$unwind": "$items"},
                                {"$group": {"_id": "prezzo medio", "prezzoMedio": {"$avg":"$items.price"}}} #$avg valore medio
])

df = pd.DataFrame(list(result))
df
# Out:
#             _id                          prezzoMedio
# 0  prezzo medio  174.3109930465015210777922642329422

# %% [markdown]
# # 6. modificare le mail che hanno il dominio .mz in .com

# %%
result = db2.vendite.update_many({"customer.email":{"$regex":".mz$"}}, #$regex \ indica che finisce con mz #.mz$  $ means "from the end"
                                          {"$set":{"customer.email":{"$replaceOne":{"input":"$email","find":".mz","replacement":".com"}}}
})
result.modified_count
# Out:
# 12

# %% [markdown]
# # 7. modificare il tag 'school' in 'education'

# %%
result = db2.vendite.find({})
df= pd.DataFrame(list(result))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 1     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 2     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# 3     5bd761dcae323e45a93ccff8 2013-08-21 09:36:07.188
# 4     5bd761dcae323e45a93ccff3 2015-07-22 02:45:20.727
# ...                        ...                     ...
# 2832  5bd761deae323e45a93ce337 2014-04-29 05:00:20.567
# 2833  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 2834  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 2835  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 2836  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'laptop', 'tags': ['electronics', 's...        Denver
# 1     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 2     [{'name': 'backpack', 'tags': ['school', 'trav...        London
# ...

# %%
result = db2.vendite.update_many({"items"})

# %% [markdown]
# # 8. aggiungere 7 anni alla data degli ordini

# %%
result = db2.vendite.update_many({"saleDate" : {"$exists" : True } },
                                           [{"$set": { "date": { "$dateAdd": { "startDate": "$saleDate", "unit": "year", "amount": 7 } } } }])

result.modified_count
# Out:
# 2837

# %% [markdown]
# # 9. trovare il prodotto venduto più costoso

# %%
result = db2.vendite.aggregate([
                             {"$unwind" : "$items"},
                             {"$unwind": "$items.price"},
    { "$group": {
        "_id": "il prodotto più costoso corrisponde a: ",
        "Risultato": {
            "$max": "$items.price"
        },
        "customerpr": {
            "$push": {
                "oggetti": "$items.name",
                "price": "$items.price",
            }
        }
       }
    },
{
    '$unwind': '$customerpr'
}, {
    "$match" : {"$expr": {"$eq":["$customerpr.price","$Risultato"]}}
}

    ])

dbRes1 = pd.DataFrame(list(result))
dbRes1
# Out:
#                                        _id Risultato  \
# 0  il prodotto più costoso corrisponde a:    1598.12
#
#                                 customerpr
# 0  {'oggetti': 'laptop', 'price': 1598.12}

# %% [markdown]
# # 10. eliminare dagli ordini tutti i prodotti "envelopes"

# %%
result = db.sales_da_modificare.update_many({}, {'$pull': { 'items': {'name': "envelopes"}}})
result.modified_count
# Out:
# 0

# %% [markdown]
# # 11. copiare la collection "vendite" nella collection "vendite_modificata"

# %%
db2.vendite.aggregate([{"$out": "vendite_modificata"}])

# %% [markdown]
# # 12. eliminare la collection "vendite"

# %%
import pymongo

str_conn = "mongodb://Santambrogio:wwwws6Ss@cluster0-shard-00-00.r4fcr.mongodb.net:27017,cluster0-shard-00-01.r4fcr.mongodb.net:27017,cluster0-shard-00-02.r4fcr.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-yc014g-shard-0&authSource=admin&retryWrites=true&w=majority"
client = pymongo.MongoClient("mongodb://Santambrogio:wwwws6Ss@cluster0-shard-00-00.r4fcr.mongodb.net:27017,cluster0-shard-00-01.r4fcr.mongodb.net:27017,cluster0-shard-00-02.r4fcr.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-yc014g-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.Santambrogio
collection = db.vendite
collection.delete_many({})   
print(collection.count_documents({}))
# Out:
# 0

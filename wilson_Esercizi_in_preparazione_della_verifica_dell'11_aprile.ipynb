# %%
import pymongo
import pandas as pd

# %%
#database prof

client = pymongo.MongoClient("mongodb://webUser:xxx123xxx@cluster0-shard-00-00.algwo.mongodb.net:27017,cluster0-shard-00-01.algwo.mongodb.net:27017,cluster0-shard-00-02.algwo.mongodb.net:27017/?ssl=true&replicaSet=atlas-am4cb3-shard-0&authSource=admin&retryWrites=true&w=majority")
client

# %%
db = client.sample_supplies
db

# %%
#ma utlizzo il mio siccome in quel del prof hanno modificato i dati

client2 = pymongo.MongoClient("mongodb://WilsonRiccardo:Ricky2004!@cluster0-shard-00-00.mwou4.mongodb.net:27017,cluster0-shard-00-01.mwou4.mongodb.net:27017,cluster0-shard-00-02.mwou4.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-kkdpdd-shard-0&authSource=admin&retryWrites=true&w=majority")

#sample supplies perchè ho scaricato i sample data su monodb atlas

db2 = client2.sample_supplies
db2
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.mwou4.mongodb.net:27017', 'cluster0-shard-00-01.mwou4.mongodb.net:27017', 'cluster0-shard-00-00.mwou4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-kkdpdd-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'sample_supplies')

# %%
#serve per copiare i dati all'interno del mio database, in una colection chiamata vendite

db2.vendite.insert_many(df.to_dict("records"))

# %%
result = db2.sales.find()
df = pd.DataFrame(list(result))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4995  5bd761deae323e45a93ce36b 2016-01-20 17:29:10.225
# 4996  5bd761deae323e45a93ce36c 2014-11-29 10:09:41.573
# 4997  5bd761deae323e45a93ce36d 2017-12-25 07:02:51.283
# 4998  5bd761deae323e45a93ce36e 2013-12-07 11:06:25.510
# 4999  5bd761deae323e45a93ce36f 2014-08-18 06:25:49.739
#
#                                                   items storeLocation  \
# 0     [{'name': 'printer paper', 'tags': ['office', ...        Denver
# 1     [{'name': 'envelopes', 'tags': ['stationary', ...       Seattle
# 2     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# ...

# %% [markdown]
# #1. cancellare tutti i document relativi al negozio di San Diego

# %%
#vedo quante sono i document che corrispondo alla condizione
result = db2.sales.find({"storeLocation" : "San Diego"})
df1 = pd.DataFrame(list(result))
df1
# Out:
#                           _id                saleDate  \
# 0    5bd761dcae323e45a93ccff4 2014-08-18 10:42:13.935
# 1    5bd761dcae323e45a93ccff6 2017-08-21 20:38:34.618
# 2    5bd761dcae323e45a93ccffa 2016-08-15 04:05:03.298
# 3    5bd761dcae323e45a93ccffe 2013-03-20 16:36:39.112
# 4    5bd761dcae323e45a93cd009 2015-11-08 06:59:18.442
# ..                        ...                     ...
# 341  5bd761deae323e45a93ce325 2015-03-30 22:47:19.228
# 342  5bd761deae323e45a93ce327 2015-03-17 02:24:29.203
# 343  5bd761deae323e45a93ce336 2017-04-02 07:22:57.842
# 344  5bd761deae323e45a93ce354 2016-09-24 15:58:04.280
# 345  5bd761deae323e45a93ce363 2017-01-11 01:31:55.384
#
#                                                  items storeLocation  \
# 0    [{'name': 'backpack', 'tags': ['school', 'trav...     San Diego
# 1    [{'name': 'printer paper', 'tags': ['office', ...     San Diego
# 2    [{'name': 'laptop', 'tags': ['electronics', 's...     San Diego
# ...

# %%
result = db2.sales.delete_many({"storeLocation": "San Diego"})
result.deleted_count
# Out:
# 346

# %%
#verifico l'avvenuta eliminazione dei dati
result = db2.sales.find()
df1 = pd.DataFrame(list(result))
df1
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce36b 2016-01-20 17:29:10.225
# 4650  5bd761deae323e45a93ce36c 2014-11-29 10:09:41.573
# 4651  5bd761deae323e45a93ce36d 2017-12-25 07:02:51.283
# 4652  5bd761deae323e45a93ce36e 2013-12-07 11:06:25.510
# 4653  5bd761deae323e45a93ce36f 2014-08-18 06:25:49.739
#
#                                                   items storeLocation  \
# 0     [{'name': 'printer paper', 'tags': ['office', ...        Denver
# 1     [{'name': 'envelopes', 'tags': ['stationary', ...       Seattle
# 2     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# ...

# %% [markdown]
# #2. invecchiare i clienti di 8 anni

# %%
#verifico l'età delle persone
result = db2.sales.find()
df2 = pd.DataFrame(list(result))
df2
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce36b 2016-01-20 17:29:10.225
# 4650  5bd761deae323e45a93ce36c 2014-11-29 10:09:41.573
# 4651  5bd761deae323e45a93ce36d 2017-12-25 07:02:51.283
# 4652  5bd761deae323e45a93ce36e 2013-12-07 11:06:25.510
# 4653  5bd761deae323e45a93ce36f 2014-08-18 06:25:49.739
#
#                                                   items storeLocation  \
# 0     [{'name': 'printer paper', 'tags': ['office', ...        Denver
# 1     [{'name': 'envelopes', 'tags': ['stationary', ...       Seattle
# 2     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# ...

# %%
#incremento l'età con l'operatore logico $inc
result = db2.sales.update_many({}, {"$inc" : {"customer.age" : 8}})
result.modified_count
# Out:
# 4654

# %%
#verifico se l'incremento sia avvenuto
result = db2.sales.find()
df2 = pd.DataFrame(list(result))
df2
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce36b 2016-01-20 17:29:10.225
# 4650  5bd761deae323e45a93ce36c 2014-11-29 10:09:41.573
# 4651  5bd761deae323e45a93ce36d 2017-12-25 07:02:51.283
# 4652  5bd761deae323e45a93ce36e 2013-12-07 11:06:25.510
# 4653  5bd761deae323e45a93ce36f 2014-08-18 06:25:49.739
#
#                                                   items storeLocation  \
# 0     [{'name': 'printer paper', 'tags': ['office', ...        Denver
# 1     [{'name': 'envelopes', 'tags': ['stationary', ...       Seattle
# 2     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# ...

# %% [markdown]
# #3. cancellare tutti i tag 'stationary'

# %%
#controllo il numero di document che contengono il tag stationary 
result = db2.sales.find({"items.tags" : "stationary"})
df3 = pd.DataFrame(list(result))
df3
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4085  5bd761deae323e45a93ce36b 2016-01-20 17:29:10.225
# 4086  5bd761deae323e45a93ce36c 2014-11-29 10:09:41.573
# 4087  5bd761deae323e45a93ce36d 2017-12-25 07:02:51.283
# 4088  5bd761deae323e45a93ce36e 2013-12-07 11:06:25.510
# 4089  5bd761deae323e45a93ce36f 2014-08-18 06:25:49.739
#
#                                                   items storeLocation  \
# 0     [{'name': 'printer paper', 'tags': ['office', ...        Denver
# 1     [{'name': 'envelopes', 'tags': ['stationary', ...       Seattle
# 2     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# ...

# %%
result = db2.sales.update_many({},{"$pull" : {"items" : { "tags": "stationary"}}})
result.modified_count
# Out:
# 4090

# %%
#verifico l'avvenuta eliminazione dei tag stationary
result = db2.sales.find({"items.tags" : "stationary"})
df3 = pd.DataFrame(list(result))
df3
#siccome non esce nulla significa che i tag sono stati eliminati
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #4. eliminare tutti i document di clienti che hanno più di 80 anni e meno di 40

# %%
#verifico quanti document corrispondo alla condizione
result = db2.sales.find({'$or': [{"customer.age" : {'$gt' : 80 }} , {"customer.age" : {'$lt' : 40 }}]})
df4 = pd.DataFrame(list(result))
df4
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff0 2017-03-21 01:54:26.657
# 1     5bd761dcae323e45a93ccff7 2017-12-08 21:40:34.527
# 2     5bd761dcae323e45a93ccffc 2015-11-12 12:06:07.052
# 3     5bd761dcae323e45a93ccffd 2015-07-27 20:05:46.464
# 4     5bd761dcae323e45a93cd000 2015-05-15 13:43:24.561
# ...                        ...                     ...
# 1005  5bd761deae323e45a93ce34a 2013-09-16 01:32:22.741
# 1006  5bd761deae323e45a93ce34e 2014-10-22 01:05:18.920
# 1007  5bd761deae323e45a93ce357 2017-07-15 09:44:26.576
# 1008  5bd761deae323e45a93ce35b 2017-07-12 06:54:17.918
# 1009  5bd761deae323e45a93ce36d 2017-12-25 07:02:51.283
#
#                                                   items storeLocation  \
# 0     [{'name': 'notepad', 'tags': ['office', 'writi...      New York
# 1     [{'name': 'laptop', 'tags': ['electronics', 's...        Denver
# 2     [{'name': 'binder', 'tags': ['school', 'genera...        Denver
# ...

# %%
result = db2.sales.delete_many({'$or': [{"customer.age" : {'$gt' : 80 }} , {"customer.age" : {'$lt' : 40 }}]})
result.deleted_count
# Out:
# 1010

# %%
result = db2.sales.find({'$or': [{"customer.age" : {'$gt' : 80 }} , {"customer.age" : {'$lt' : 40 }}]})
df4 = pd.DataFrame(list(result))
df4
##siccome non esce nulla significa che i tag sono stati eliminati
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #5. calcolare il prezzo medio degli items

# %%
result = db2.sales.aggregate([{"$unwind": "$items"},
                              {"$group": {"_id": "prezzo medio", "prezzoMedio": {"$avg":"$items.price"}}},
                              { "$project": { "prezzoMedio": { "$round": [ "$prezzoMedio", 2 ] } } }
])

df5 = pd.DataFrame(list(result))
df5
#ho utilizzato $round per non visualizzare l'intero numero
# Out:
#             _id prezzoMedio
# 0  prezzo medio      172.51

# %% [markdown]
# #6. modificare le mail che hanno il dominio .mz in .com

# %%
result = db2.sales.find({"customer.email" :{"$regex":".mz$"}})
df3 = pd.DataFrame(list(result))
df3

# %%
result = db2.sales.update_many({"customer.email": { "$regex": ".mz$" } }, #fin qui è giusto                                                                     
                               {"$set": { "customer":{"email": {"$replaceOne": { "input": "$email", "find": ".mz", "replacement": ".com" }}}}
  }
)
result.modified_count
# Out:
# 14

# %% [markdown]
# sbagliato perchè ho sostuito l'intera mail con <{"customer.email": { "$regex": '{"$replaceOne": { "input": "$email", "find": ".mz", "replacement": ".com" }}'}}>

# %% [markdown]
# #7. modificare il tag 'school' in 'education'

# %%
result = db2.sales.find({"items.tags" : "school"})
df7 = pd.DataFrame(list(result))
df7
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 3442  5bd761deae323e45a93ce36a 2013-10-06 22:39:37.868
# 3443  5bd761deae323e45a93ce36b 2016-01-20 17:29:10.225
# 3444  5bd761deae323e45a93ce36c 2014-11-29 10:09:41.573
# 3445  5bd761deae323e45a93ce36e 2013-12-07 11:06:25.510
# 3446  5bd761deae323e45a93ce36f 2014-08-18 06:25:49.739
#
#                                                   items storeLocation  \
# 0     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 1     [{'name': 'binder', 'tags': ['school', 'genera...       Seattle
# 2     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# ...

# %%
result = db2.sales.update_many({ "items.tags": { "$regex": "school" } },[                                                                      
                              {"$set": { "items": {"tags": {"$replaceAll": { "input": "$tags", "find": "school", "replacement": "education" }}}}
  }]
)
result.modified_count
# Out:
# 0

# %% [markdown]
# sbagliato perchè i tag sono stati sostituiti con None

# %% [markdown]
# #8. aggiungere 7 anni alla data degli ordini

# %%
#verifico le date
result = db2.sales.find()
df8= pd.DataFrame(list(result))
df8
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 3639  5bd761deae323e45a93ce36a 2013-10-06 22:39:37.868
# 3640  5bd761deae323e45a93ce36b 2016-01-20 17:29:10.225
# 3641  5bd761deae323e45a93ce36c 2014-11-29 10:09:41.573
# 3642  5bd761deae323e45a93ce36e 2013-12-07 11:06:25.510
# 3643  5bd761deae323e45a93ce36f 2014-08-18 06:25:49.739
#
#                                                   items storeLocation  \
# 0     [{'name': 'notepad', 'tags': None, 'price': 35...        Denver
# 1     [{'name': 'binder', 'tags': None, 'price': 28....       Seattle
# 2     [{'name': 'notepad', 'tags': None, 'price': 30...        Denver
# ...

# %%
result = db2.sales.update_many(
  { "saleDate" : { "$exists" : "true" }},
  [{ "$set": { "saleDate": { "$dateAdd": { "startDate": "$saleDate", "unit": "year", "amount": 7}}}}]
)
result.modified_count
# Out:
# 3644

# %%
result = db2.sales.find()
df = pd.DataFrame(list(result))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2022-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2022-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2024-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2022-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2024-12-03 18:39:48.253
# ...                        ...                     ...
# 3639  5bd761deae323e45a93ce36a 2020-10-06 22:39:37.868
# 3640  5bd761deae323e45a93ce36b 2023-01-20 17:29:10.225
# 3641  5bd761deae323e45a93ce36c 2021-11-29 10:09:41.573
# 3642  5bd761deae323e45a93ce36e 2020-12-07 11:06:25.510
# 3643  5bd761deae323e45a93ce36f 2021-08-18 06:25:49.739
#
#                                                   items storeLocation  \
# 0     [{'name': 'notepad', 'tags': None, 'price': 35...        Denver
# 1     [{'name': 'binder', 'tags': None, 'price': 28....       Seattle
# 2     [{'name': 'notepad', 'tags': None, 'price': 30...        Denver
# ...

# %% [markdown]
# #9. trovare il prodotto venduto più costoso

# %%
result = db2.sales.aggregate([{}

])

dbRes = pd.DataFrame(list(result))
dbRes
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-55-05e4371bf130> in <module>()
# ----> 1 result = db2.sales.aggregate([{}
#       2
#       3 ])
#       4
#       5 dbRes = pd.DataFrame(list(result))
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in aggregate(self, pipeline, session, **kwargs)
#    2108                 session=s,
#    2109                 explicit_session=session is not None,
# -> 2110                 **kwargs
#    2111             )
#    2112
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, **kwargs)
#    2028             cmd.get_read_preference(session),
#    2029             session,
# -> 2030             retryable=not cmd._performs_write,
#    2031         )
#    2032
#
# ...

# %% [markdown]
# #10. eliminare dagli ordini tutti i prodotti "envelopes"

# %% [markdown]
# per questo esercizio utlizzo il database di visio perchè il mio è smonco

# %%
client = pymongo.MongoClient("mongodb://Emanuele-Visioli:EMAnuele25102004@cluster0-shard-00-00.x7fma.mongodb.net:27017,cluster0-shard-00-01.x7fma.mongodb.net:27017,cluster0-shard-00-02.x7fma.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-566dc8-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.sample_supplies
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.x7fma.mongodb.net:27017', 'cluster0-shard-00-00.x7fma.mongodb.net:27017', 'cluster0-shard-00-01.x7fma.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-566dc8-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'sample_supplies')

# %%
db.sales.aggregate([{ "$match": {} }, { "$out": "sales_da_modificare" }])

# %%
result = db.sales_da_modificare.find()
df = pd.DataFrame(list(result))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 4650  5bd761deae323e45a93ce33e 2015-11-25 21:06:13.187
# 4651  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 4652  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 4653  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'pens', 'tags': ['writing', 'office'...       Seattle
# 1     [{'name': 'printer paper', 'tags': ['office', ...      New York
# 2     [{'name': 'pens', 'tags': ['writing', 'office'...        Denver
# ...

# %%
result = db.sales_da_modificare.find({"items.name": "envelopes"})
df = pd.DataFrame(list(result))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# 3     5bd761dcae323e45a93ccff8 2013-08-21 09:36:07.188
# 4     5bd761dcae323e45a93ccff3 2015-07-22 02:45:20.727
# ...                        ...                     ...
# 3081  5bd761deae323e45a93ce321 2016-05-28 14:56:36.624
# 3082  5bd761deae323e45a93ce32e 2014-04-15 15:39:48.240
# 3083  5bd761deae323e45a93ce337 2014-04-29 05:00:20.567
# 3084  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 3085  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
#
#                                                   items storeLocation  \
# 0     [{'name': 'pens', 'tags': ['writing', 'office'...       Seattle
# 1     [{'name': 'printer paper', 'tags': ['office', ...      New York
# 2     [{'name': 'backpack', 'tags': ['school', 'trav...        London
# ...

# %%
result = db.sales_da_modificare.update_many({}, {'$pull': { 'items': {'name': "envelopes"}}})
result.modified_count
# Out:
# 3086

# %%
result = db.sales_da_modificare.find({"customer.email": "vo@guflan.jp"})
df = pd.DataFrame(list(result))
df
#abbiamo verificato che non tutta la clonna venga eliminata
# Out:
#                         _id                saleDate  \
# 0  5bd761deae323e45a93ce337 2014-04-29 05:00:20.567
#
#                                                items storeLocation  \
# 0  [{'name': 'binder', 'tags': ['school', 'genera...       Seattle
#
#                                             customer  couponUsed  \
# 0  {'gender': 'F', 'age': 57, 'email': 'vo@guflan...       False
#
#   purchaseMethod
# 0         Online
